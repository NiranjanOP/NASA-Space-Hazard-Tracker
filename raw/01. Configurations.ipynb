-- %%
CREATE CATALOG nasa_analytics
MANAGED LOCATION 'abfss://nasa-analytics@deacourseextdl0070.dfs.core.windows.net/'
COMMENT 'Catalog for NASA Analytics project';

-- %%
USE CATALOG nasa_analytics;

CREATE SCHEMA raw;
CREATE SCHEMA bronze;
CREATE SCHEMA silver;
CREATE SCHEMA gold;
